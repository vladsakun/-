# %% [markdown]
# **Лабораторна робота 2.2**
#
# **студента групи ФІТ 4-4**
#
# **Сакуна Владислава Олександровича**
#
# Тема: побудова двонаправленої RNN для розрахунку функції із шумом

# %% [markdown]
# **Завдання**
#
# Побудувати двонаправлену RNN для розрахунку функції із шумом. Підібрати власну архитектуру, кількість шарів, функції активації. Побудувати графік. N = 10000 data = np.array([np.функція for x in range(N)]) + 0.1*np.random.randn(N) В якості функції взяти тригонометричну функцію, наприклад 𝑐𝑜𝑠(3𝑥) , 𝑠𝑖𝑛(𝑥 ∕ 5) , 𝑠𝑖𝑛(𝑥 + 3) ∕ 2 і тд.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

N = 10000
X = np.random.rand(N) * 10
Y = np.cos(3*X) + 0.1 * np.random.randn(N)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_shape=(1,), activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X, Y, epochs=10, batch_size=32, verbose=1)
predictions = model.predict(X)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.scatter(X, Y, label='Дані')
plt.scatter(X, predictions, color='r', label='Прогнози')
plt.title('Співставлення Даних та Прогнозів')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Функція Втрат')
plt.xlabel('Епохи')
plt.ylabel('Втрати')

plt.show()
# Out:
# Epoch 1/10
# 313/313 [==============================] - 6s 9ms/step - loss: 0.5142
# Epoch 2/10
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4905
# Epoch 3/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4837
# Epoch 4/10
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4808
# Epoch 5/10
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4748
# Epoch 6/10
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4699
# Epoch 7/10
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4541
# Epoch 8/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4316
# Epoch 9/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4218
# Epoch 10/10
# ...
# 313/313 [==============================] - 0s 1ms/step
